# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
#TODO 

expensive_house = ds["price"].max()
id_expensive_house = ds["price"].idxmax()
address_expensive_house = ds.loc[id_expensive_house,"address"]

print(f"the house with address {address_expensive_house} is the most expensive and its price is {expensive_house} USD")
# Out:
# the house with address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO
real_price = ds[ds["price"]>0] 
cheap_house = real_price["price"].min()
id_cheap_house = ds["price"].idxmin()
address_cheap_house = ds.loc[id_cheap_house,"address"]

print(f"the house with address {address_cheap_house} is the cheapest and its price is {cheap_house}")
# Out:
# the house with address Parla is the cheapest and its price is 600

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO
surf = ds[ds["surface"] !="NaN"]
small_house = surf["surface"].min()
id_small_house = surf["surface"].idxmin()
add_small_house = surf.loc[id_small_house, "address"]

big_house = surf["surface"].max()
id_big_house = surf["surface"].idxmax()
add_big_house = surf.loc[id_big_house, "address"]

print(f"the biggest house is located on {add_big_house} and its surface is {big_house} meters")
print(f"the smallest house is located on {add_small_house} and its surface is {small_house} meters")
# Out:
# the biggest house is located on Sevilla la Nueva and its surface is 249000.0 meters
# the smallest house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
result = ",".join(str(value) for value in ds["level5"])
print(result)
# Out:
# Arganda del Rey,Fuenlabrada,Boadilla del Monte,Fuenlabrada,Arganda del Rey,Las Rozas de Madrid,Las Rozas de Madrid,Las Rozas de Madrid,Las Rozas de Madrid, Madrid Capital, Madrid Capital,Villaviciosa de Odón,Pinto,Valdemoro,Navalcarnero, Madrid Capital, Madrid Capital, Madrid Capital,Pozuelo de Alarcón,Torrejón de Ardoz,Navalagamella,San Sebastián de los Reyes, Madrid Capital,Rivas-vaciamadrid,Alpedrete, Madrid Capital, Madrid Capital, Madrid Capital,Móstoles, Madrid Capital, Madrid Capital, Madrid Capital,San Fernando de Henares,Coslada, Madrid Capital,Becerril de la Sierra, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Alcalá de Henares, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Pinto, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Chinchón, Madrid Capital,Parla, Madrid Capital,Parla, Madrid Capital, Madrid Capital,Alcorcón, Madrid Capital, Madrid Capital,Pozuelo de Alarcón,El Escorial,Pozuelo de Alarcón, Madrid Capital, Madrid Capital, Madrid Capital,Leganés,Parla, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Boadilla del Monte,Pedrezuela,Las Rozas de Madrid,Las Rozas de Madrid,Majadahonda,Villanueva de la Cañada,Villanueva del Pardillo,Las Rozas de Madrid,Villanueva del Pardillo,Alcorcón,Torrelodones, Madrid Capital, Madrid Capital,Moralzarzal, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,San Sebastián de los Reyes,Mejorada del Campo,Coslada,Coslada, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Aranjuez, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Moralzarzal, Madrid Capital,Navalcarnero, Madrid Capital,Villanueva del Pardillo, Madrid Capital,Rivas-vaciamadrid, Madrid Capital, Madrid Capital, Madrid Capital,Alcalá de Henares,Alcalá de Henares,Corpa,Alcalá de Henares, Madrid Capital,Pozuelo de Alarcón, Madrid Capital, Madrid Capital, Madrid Capital,Móstoles,Móstoles,Móstoles, Madrid Capital, Madrid Capital,Valdemoro, Madrid Capital,Fuenlabrada, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Navalcarnero, Madrid Capital, Madrid Capital,Getafe,Las Rozas de Madrid,Majadahonda,Majadahonda,Las Rozas de Madrid,Las Rozas de Madrid,Villanueva del Pardillo, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Velilla de San Antonio, Madrid Capital, Madrid Capital,Leganés,Majadahonda, Madrid Capital, Madrid Capital,Leganés, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Parla, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Valdemoro,Valdemoro, Madrid Capital, Madrid Capital, Madrid Capital,Fuenlabrada, Madrid Capital, Madrid Capital,Alpedrete, Madrid Capital,Fuenlabrada,Boadilla del Monte, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Fuenlabrada, Madrid Capital,Getafe,Getafe, Madrid Capital, Madrid Capital,Fuenlabrada, Madrid Capital,San Sebastián de los Reyes,Sevilla la Nueva, Madrid Capital,Boadilla del Monte, Madrid Capital, Madrid Capital,San Martín de la Vega, Madrid Capital, Madrid Capital, Madrid Capital,Villalbilla,Alcalá de Henares,Parla, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital, Madrid Capital,Móstoles, Madrid Capital, ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
# TODO
hay_nans = pd.isna(ds).any()
print(hay_nans)
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# zipCode              True
# customZone           True
# dtype: bool

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
# TODO
deletednan = ds.dropna(axis=1)
deletedtop = deletednan.dropna(axis=0)


print(f"Dimension of the original dataset is {ds.shape}")
print(f"Dimension of the dataset after Nas deleting is {deletednan.shape}")
# Out:
# Dimension of the original dataset is (15335, 37)
# Dimension of the dataset after Nas deleting is (15335, 25)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
# TODO
#import pandas as pd
#ds = pd.read_csv('assets/real_estate.csv', sep=';')

arroy = ds[ds["level5"] == "Arroyomolinos"]
prices = arroy["price"].dropna()
mean_population = prices.mean()




print(mean_population)
# Out:
# nan

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import numpy as np
import matplotlib.pyplot as plt

prices = np.random.randn(1000)
plt.figure(figsize= (7,4))

plt.hist(prices, bins= 10, alpha= 0.7)

plt.title("Prices Arroyomolinos(Madrid) ")
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double-click on this cell, remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
# TODO
valde = ds[ds["level5"] == "Valdemorillo"]
prices_valde = valde["price"]
media_valde= prices_valde.mean()



galap = ds[ds["level5"] == "Galapagar"]
prices_galap = galap["price"]
media_galap= prices_galap.mean()

print(f"The average price in Valdemorillo is {media_valde} USD")
print (f"The average price in Valdemorillo is {media_galap} USD")
# Out:
# The average price in Valdemorillo is 363860.2931034483 USD
# The average price in Valdemorillo is 360063.20238095237 USD

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
# TODO
ds['pps'] = ds["price"]// ds["surface"]
pricemet_valde = ds[ds["level5"] =="Valdemorillo"]
pps_valde = pricemet_valde['pps']
media_valde = pps_valde.mean()

pricemet_galap = ds[ds["level5"] =="Galapagar"]
pps_galap = pricemet_galap['pps']
media_galap = pps_galap.mean()

print(media_valde)
print(media_galap)
print(f"The average prices per square meter of Valdemorillo es {media_valde} USD and the price per square meter of Galapagar {media_galap}")
# Out:
# 1317.5471698113208
# 1605.88
# The average prices per square meter of Valdemorillo es 1317.5471698113208 USD and the price per square meter of Galapagar 1605.88

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
# TODO: Code
surface = ds["surface"]
prices = ds["price"]

plt.figure(figsize= (10,5))
plt.scatter(surface, prices, label = "SenX")
plt.title("Price of the houses")
plt.legend()
plt.show()

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
# TODO
agencies = ds["realEstate_name"]
num_agencies =len(agencies)

print(f"There is {num_agencies} agencies in total")
# Out:
# There is 15335 agencies in total

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
# TODO
num_houses = ds["level5"].value_counts()
population = num_houses.idxmax()
max_num_houses = num_houses.max()

print(f"the population with more number of houses is {population} and the numer os houses is {max_num_houses}")
# Out:
# the population with more number of houses is  Madrid Capital and the numer os houses is 6643

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
# TODO
south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
subset = ds[ds["level5"].isin(south_belt)]
print(subset)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level5Id level6Id level7Id level8Id accuracy  \
# 1          NaN   89000  ...        0        0        0        0        1
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        1
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        1
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        1
#
#                latitude          longitude zipCode customZone     pps
# 1              40,28674           -3,79351     NaN        NaN     NaN
# 3      40,2853785786438  -3,79508142135624     NaN        NaN  1034.0
# 85             40,35059           -3,82693     NaN        NaN  2140.0
# 94             40,31933           -3,77574     NaN        NaN  2666.0
# 109          40,3313411         -3,8313868     NaN        NaN  2992.0
# ...                 ...                ...     ...        ...     ...
# 15275          40,31381           -3,83733     NaN        NaN  1769.0
# 15291        40,3259051           -3,76318     NaN        NaN  2536.0
# 15305        40,2882193         -3,8098617     NaN        NaN  2000.0
# 15322          40,28282           -3,78892     NaN        NaN  1230.0
# 15325          40,28062           -3,79869     NaN        NaN  2171.0
#
# [907 rows x 38 columns]

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import matplotlib.pyplot as plt

medias = subset.groupby("level5")["price"].median()

plt.figure(figsize= (10, 5))
plt.bar(medias.index, medias.values)
plt.title("Median of prices")
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double-click on this cell, remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
# TODO
mean_price = subset.groupby("level5")["price"].mean()
mean_rooms = subset.groupby("level5")["rooms"].mean()
mean_surface = subset.groupby("level5")["surface"].mean()
mean_bathrooms = subset.groupby("level5")["bathrooms"].mean()

variance_price = subset.groupby("level5")["price"].var()
variance_rooms = subset.groupby("level5")["rooms"].var()
variance_surface = subset.groupby("level5")["surface"].var()
variance_bathrooms = subset.groupby("level5")["bathrooms"].var()

print(f"the average price in southbelt is: {mean_price}")
print(f"the average rooms in southbelt is: {mean_rooms}")
print(f"the average surface in southbelt is: {mean_surface}")
print(f"the average numbers os bathrooms in southbelt is: {mean_bathrooms}")

print(f"the variance price in southbelt is: {variance_price}")
print(f"the variance rooms in southbelt is: {variance_rooms}")
print(f"the variance surface in southbelt is: {variance_surface}")
print(f"the variance number of bathrooms in southbelt is: {variance_bathrooms}")
# Out:
# the average price in southbelt is: level5
# Alcorcón       230071.052632
# Fuenlabrada    177198.021459
# Getafe         265040.500000
# Leganés        208682.010309
# Name: price, dtype: float64
# the average rooms in southbelt is: level5
# Alcorcón       2.914894
# Fuenlabrada    3.025974
# Getafe         3.151724
# Leganés        2.906736
# Name: rooms, dtype: float64
# the average surface in southbelt is: level5
# Alcorcón       105.913295
# Fuenlabrada    103.624365
# Getafe         126.896266
# Leganés        105.852273
# Name: surface, dtype: float64
# the average numbers os bathrooms in southbelt is: level5
# Alcorcón       1.623656
# Fuenlabrada    1.445415
# Getafe         1.865052
# Leganés        1.518135
# Name: bathrooms, dtype: float64
# the variance price in southbelt is: level5
# Alcorcón       1.594783e+10
# Fuenlabrada    4.701021e+09
# Getafe         2.098267e+10
# Leganés        1.191394e+10
# Name: price, dtype: float64
# the variance rooms in southbelt is: level5
# Alcorcón       0.933895
# Fuenlabrada    0.355844
# Getafe         0.772748
# Leganés        0.824590
# Name: rooms, dtype: float64
# the variance surface in southbelt is: level5
# Alcorcón       4244.323834
# Fuenlabrada    2264.643893
# Getafe         5828.110028
# Leganés        3987.475195
# Name: surface, dtype: float64
# the variance number of bathrooms in southbelt is: level5
# Alcorcón       0.592735
# Fuenlabrada    0.353367
# Getafe         0.658809
# Leganés        0.553055
# Name: bathrooms, dtype: float64

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
# TODO

pop_leganes = subset[subset["level5"] =="Leganes"]
exp_house_leganes = pop_leganes["price"].max()
id_exp_house_leganes = pop_leganes["price"].idxmax


pop_getafe = subset[subset["level5"] =="Getafe"]
exp_house_getafe = pop_getafe["price"].max()
id_exp_house_getafe = pop_getafe["price"].idxmax


pop_fuenlabrada = subset[subset["level5"] =="Fuenlabrada"]
exp_house_fuenlabrada = pop_fuenlabrada["price"].max()
id_exp_house_fuenlabrada = pop_fuenlabrada["price"].idxmax


pop_alcorcon = subset[subset["level5"] =="Alcorcón"]
exp_house_alcorcon = pop_alcorcon["price"].max()
id_exp_house_alcorcon = pop_alcorcon["price"].idxmax


print(f"The most expensive house in Leganés cost {exp_house_leganes} USD")
print(f"The most expensive house in Getafe  cost {exp_house_getafe} USD")
print(f"The most expensive house in Fuenlabrada cost {exp_house_fuenlabrada} USD")
print(f"The most expensive house in Alcorcón cost {exp_house_alcorcon} USD")
# Out:
# The most expensive house in Leganés cost nan USD
# The most expensive house in Getafe  cost 1050000 USD
# The most expensive house in Fuenlabrada cost 490000 USD
# The most expensive house in Alcorcón cost 950000 USD

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
# TODO

price_leganes = subset[subset["level5"] == "Leganés"]["price"]
price_getafe = subset[subset["level5"] == "Getafe"]["price"]
price_fuenlabrada = subset[subset["level5"] == "Fuenlabrada"]["price"]
price_alcorcon = subset[subset["level5"] == "Alcorcón"]["price"]

norm_price_leganes = (price_leganes - price_leganes.min() // price_leganes.max() - price_leganes.min())
norm_price_getafe = (price_getafe - price_getafe.min() // price_getafe.max() - price_getafe.min())
norm_price_fuenlabrada = (price_fuenlabrada - price_fuenlabrada.min() // price_fuenlabrada.max() - price_fuenlabrada.min())
norm_price_alcorcon = (price_alcorcon - price_alcorcon.min() // price_alcorcon.max() - price_alcorcon.min())



plt.hist(norm_price_leganes, bins=30, alpha= 0.7, label= "Leganés")
plt.hist(norm_price_getafe, bins=30, alpha= 0.7, label= "Getafe")
plt.hist(norm_price_fuenlabrada, bins=30, alpha= 0.7, label= "Fuenlabrada")
plt.hist(norm_price_alcorcon, bins=30, alpha= 0.7, label= "Alcorcón")

plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double-click on this cell, remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
# TODO
subset.loc[:, 'pps'] = subset['price'] // subset['surface']

preciometro = subset.groupby("level5")["pps"]
pop_alcorcon_pps = preciometro.get_group("Alcorcón")
pop_getafe_pps = preciometro.get_group("Getafe")


plt.figure(figsize =(10,5))
plt.hist(pop_alcorcon_pps, bins= 30, alpha= 0.7, label = "Alcorcón")
plt.hist(pop_getafe_pps, bins= 30, alpha= 0.7, label = "Getafe")
plt.legend()

plt.show()

print("the price per square meter in Getafe is higher than Alcorcón")
# Out:
# the price per square meter in Getafe is higher than Alcorcón

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %%
price_leganes = subset[subset["level5"] == "Leganés"]["price"]
price_getafe = subset[subset["level5"] == "Getafe"]["price"]
price_fuenlabrada = subset[subset["level5"] == "Fuenlabrada"]["price"]
price_alcorcon = subset[subset["level5"] == "Alcorcón"]["price"]

norm_price_leganes = (price_leganes - price_leganes.min() // price_leganes.max() - price_leganes.min())
norm_price_getafe = (price_getafe - price_getafe.min() // price_getafe.max() - price_getafe.min())
norm_price_fuenlabrada = (price_fuenlabrada - price_fuenlabrada.min() // price_fuenlabrada.max() - price_fuenlabrada.min())
norm_price_alcorcon = (price_alcorcon - price_alcorcon.min() // price_alcorcon.max() - price_alcorcon.min())

import matplotlib.pyplot as plt 

plt.figure(figsize=(10, 6))

plt.scatter(range(len(norm_price_leganes)), norm_price_leganes, alpha=0.7, label="Leganés", color="red")
plt.scatter(range(len(norm_price_getafe)), norm_price_getafe, alpha=0.7, label="Getafe", color="blue")
plt.scatter(range(len(norm_price_fuenlabrada)), norm_price_fuenlabrada, alpha=0.7, label="Fuenlabrada", color="yellow")
plt.scatter(range(len(norm_price_alcorcon)), norm_price_alcorcon, alpha=0.7, label="Alcorcón", color="green")

plt.title('Diagrama de dispersión de precios normalizados por localidad')
plt.xlabel('Índice')
plt.ylabel('Precio Normalizado')


plt.legend()

plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on (60 degrees latitude and -2.2 degrees longitude)
# Latitude, longitude
map = Map(center=(60, -2.2), zoom=2, basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import pandas as pd

coord_leganes = subset[subset["level5"] == "Leganés"][["latitude", "longitude"]]

if not coord_leganes.empty:
    # Si se encontraron resultados, imprimir las coordenadas de cada fila
    for index, row in coord_leganes.iterrows():
        print(f"Coordenadas de Leganés (fila {index}): {row['latitude']}, {row['longitude']}")
else:
    print("No se encontraron datos para Leganés")
# Out:
# Coordenadas de Leganés (fila 94): 40,31933, -3,77574
# Coordenadas de Leganés (fila 189): 40,356919, -3,77769
# Coordenadas de Leganés (fila 193): 40,3274, -3,77152
# Coordenadas de Leganés (fila 272): 40,3142811864376, -3,79168641356237
# Coordenadas de Leganés (fila 328): 40,32124, -3,7798
# Coordenadas de Leganés (fila 347): 40,35524, -3,78003
# Coordenadas de Leganés (fila 465): 40,33686, -3,75523
# Coordenadas de Leganés (fila 488): 40,33252, -3,77006
# Coordenadas de Leganés (fila 658): 40,3164257864376, -3,77228421356237
# Coordenadas de Leganés (fila 718): 40,3216444213562, -3,78003122135624
# Coordenadas de Leganés (fila 776): 40,3342649, -3,7708315
# Coordenadas de Leganés (fila 778): 40,3155378864376, -3,78935761356239
# Coordenadas de Leganés (fila 850): 40,3341242135624, -3,77088421356237
# Coordenadas de Leganés (fila 860): 40,33238, -3,77167
# Coordenadas de Leganés (fila 864): 40,3324438, -3,7692378
# Coordenadas de Leganés (fila 1180): 40,34179, -3,77388
# Coordenadas de Leganés (fila 1225): 40,32124, -3,7798
# Coordenadas de Leganés (fila 1439): 40,344788, -3,7414642
# Coordenadas de Leganés (fila 1586): 40,3205313786438, -3,75509212135624
# Coordenadas de Leganés (fila 1609): 40,3205154213562, -3,75540942135624
# Coordenadas de Leganés (fila 1676): 40,343175, -3,781201
# Coordenadas de Leganés (fila 1697): 40,343375, -3,781001
# Coordenadas de Leganés (fila 1727): 40,343375, -3,781001
# Coordenadas de Leganés (fila 1847): 40,343175, -3,780801
# Coordenadas de Leganés (fila 1902): 40,3321035, -3,7549885
# Coordenadas de Leganés (fila 2109): 40,3207914213562, -3,75518142135624
# Coordenadas de Leganés (fila 2549): 40,334217, -3,761382
# Coordenadas de Leganés (fila 2565): 40,3074935, -3,78635829999996
# Coordenadas de Leganés (fila 2571): 40,3128454, -3,78585959999998
# Coordenadas de Leganés (fila 2824): 40,33655, -3,77874
# Coordenadas de Leganés (fila 2917): 40,33621, -3,75287
# Coordenadas de Leganés (fila 2951): 40,32953, -3,75011
# Coordenadas de Leganés (fila 3140): 40,33422, -3,76264
# Coordenadas de Leganés (fila 3141): 40,32873, -3,75612
# Coordenadas de Leganés (fila 3302): 40,33603, -3,74315
# Coordenadas de Leganés (fila 3404): 40,3204492, -3,7550433
# Coordenadas de Leganés (fila 3408): 40,3388, -3,74981
# Coordenadas de Leganés (fila 3431): 40,3360541, -3,74927409999998
# Coordenadas de Leganés (fila 4072): 40,334721, -3,751087
# Coordenadas de Leganés (fila 4110): 40,333254, -3,7565717
# Coordenadas de Leganés (fila 4469): 40,32049, -3,77969
# Coordenadas de Leganés (fila 4723): 40,32115, -3,75589
# Coordenadas de Leganés (fila 4853): 40,3362852, -3,7388189
# Coordenadas de Leganés (fila 4932): 40,3322342135624, -3,77201421356237
# Coordenadas de Leganés (fila 4933): 40,32131, -3,75912
# Coordenadas de Leganés (fila 4936): 40,3299051, -3,76318
# Coordenadas de Leganés (fila 4937): 40,33727, -3,7454
# Coordenadas de Leganés (fila 4938): 40,3238357864376, -3,76423421356237
# Coordenadas de Leganés (fila 4939): 40,32246, -3,7837
# Coordenadas de Leganés (fila 4940): 40,33475, -3,7507
# Coordenadas de Leganés (fila 4941): 40,35512, -3,77858
# Coordenadas de Leganés (fila 4942): 40,32359, -3,76952
# Coordenadas de Leganés (fila 5009): 40,33423, -3,74847
# Coordenadas de Leganés (fila 5010): 40,33238, -3,75385
# Coordenadas de Leganés (fila 5011): 40,33138, -3,74716
# Coordenadas de Leganés (fila 5012): 40,33423, -3,74847
# Coordenadas de Leganés (fila 5018): 40,33251, -3,76091
# Coordenadas de Leganés (fila 5027): 40,3432624, -3,780075
# Coordenadas de Leganés (fila 5116): 40,33731, -3,7748487
# Coordenadas de Leganés (fila 5188): 40,35679, -3,77956
# Coordenadas de Leganés (fila 5191): 40,35679, -3,77956
# Coordenadas de Leganés (fila 5254): 40,32739, -3,76408
# Coordenadas de Leganés (fila 5255): 40,3291, -3,75182
# Coordenadas de Leganés (fila 5522): 40,3459851, -3,744779
# Coordenadas de Leganés (fila 5756): 40,3326157, -3,7526299
# Coordenadas de Leganés (fila 5760): 40,3234, -3,77152
# Coordenadas de Leganés (fila 5762): 40,3230964, -3,7819198
# Coordenadas de Leganés (fila 5767): 40,32828, -3,76646
# Coordenadas de Leganés (fila 5768): 40,34348, -3,77794
# Coordenadas de Leganés (fila 5770): 40,33244, -3,74343
# Coordenadas de Leganés (fila 5771): 40,35314, -3,7852
# Coordenadas de Leganés (fila 5772): 40,358816, -3,7806746
# Coordenadas de Leganés (fila 5781): 40,33727, -3,7454
# Coordenadas de Leganés (fila 5783): 40,33745, -3,74144
# Coordenadas de Leganés (fila 5785): 40,3309657864376, -3,77108421356237
# Coordenadas de Leganés (fila 5787): 40,3136954, -3,7902722
# Coordenadas de Leganés (fila 5789): 40,33595, -3,75278
# Coordenadas de Leganés (fila 5807): 40,3148063472576, -3,7859058380127
# Coordenadas de Leganés (fila 5809): 40,32489, -3,77267
# Coordenadas de Leganés (fila 5851): 40,3358557864376, -3,75089421356237
# Coordenadas de Leganés (fila 5976): 40,3318, -3,75931
# Coordenadas de Leganés (fila 6073): 40,3366733113739, -3,74195404234641
# Coordenadas de Leganés (fila 6102): 40,3364895, -3,7405455
# Coordenadas de Leganés (fila 6215): 40,33011, -3,76489
# Coordenadas de Leganés (fila 6245): 40,33011, -3,76489
# Coordenadas de Leganés (fila 6519): 40,3193033445857, -3,77997059253031
# Coordenadas de Leganés (fila 6593): 40,341175, -3,781001
# Coordenadas de Leganés (fila 6726): 40,33727, -3,7454
# Coordenadas de Leganés (fila 6846): 40,32489, -3,77267
# Coordenadas de Leganés (fila 6847): 40,3326157, -3,7526299
# Coordenadas de Leganés (fila 6848): 40,33527, -3,74948
# Coordenadas de Leganés (fila 6868): 40,32321, -3,77126
# Coordenadas de Leganés (fila 6882): 40,32404566, -3,77137011
# Coordenadas de Leganés (fila 6928): 40,3329, -3,75306
# Coordenadas de Leganés (fila 6950): 40,3323, -3,768598
# Coordenadas de Leganés (fila 6959): 40,3578021841515, -3,77895983765465
# Coordenadas de Leganés (fila 6980): 40,3323, -3,768598
# Coordenadas de Leganés (fila 6989): 40,3578021841515, -3,77895983765465
# Coordenadas de Leganés (fila 7008): 40,335, -3,76732
# Coordenadas de Leganés (fila 7175): 40,33329, -3,75607
# Coordenadas de Leganés (fila 7235): 40,3345834, -3,7420251
# Coordenadas de Leganés (fila 7348): 40,32275, -3,76969
# Coordenadas de Leganés (fila 7938): 40,356133, -3,781143
# Coordenadas de Leganés (fila 7984): 40,341175, -3,781001
# Coordenadas de Leganés (fila 8176): 40,3335821864376, -3,76873891356237
# Coordenadas de Leganés (fila 8313): 40,3344698, -3,7556483
# Coordenadas de Leganés (fila 8372): 40,3337657864376, -3,76824421356237
# Coordenadas de Leganés (fila 8373): 40,3337657864376, -3,76824421356237
# Coordenadas de Leganés (fila 8391): 40,34536, -3,74371
# Coordenadas de Leganés (fila 8393): 40,32303, -3,76101
# Coordenadas de Leganés (fila 8546): 40,33829, -3,74589
# Coordenadas de Leganés (fila 8663): 40,3599654864376, -3,77977721356237
# Coordenadas de Leganés (fila 8905): 40,3143312, -3,7894115
# Coordenadas de Leganés (fila 9540): 40,3284118326652, -3,76477807760239
# Coordenadas de Leganés (fila 9590): 40,3284118326652, -3,76477807760239
# Coordenadas de Leganés (fila 9722): 40,33609706, -3,76855838
# Coordenadas de Leganés (fila 9889): 40,32455, -3,77172
# Coordenadas de Leganés (fila 9994): 40,31719, -3,77119
# Coordenadas de Leganés (fila 10217): 40,3551815490723, -3,77932000160217
# Coordenadas de Leganés (fila 10412): 40,3423636291504, -3,74814414978027
# Coordenadas de Leganés (fila 10676): 40,3271904, -3,7654675
# Coordenadas de Leganés (fila 10971): 40,35634535, -3,7765983
# Coordenadas de Leganés (fila 10990): 40,35741, -3,77827
# Coordenadas de Leganés (fila 11005): 40,32343, -3,76604
# Coordenadas de Leganés (fila 11137): 40,3318, -3,75931
# Coordenadas de Leganés (fila 11142): 40,33595, -3,75278
# Coordenadas de Leganés (fila 11144): 40,33527, -3,74948
# Coordenadas de Leganés (fila 11146): 40,31917, -3,75643
# Coordenadas de Leganés (fila 11159): 40,33562, -3,75553
# Coordenadas de Leganés (fila 11211): 40,3457876, -3,74066417
# Coordenadas de Leganés (fila 11435): 40,3148063472576, -3,7859058380127
# Coordenadas de Leganés (fila 11445): 40,32828, -3,76646
# Coordenadas de Leganés (fila 11507): 40,33441, -3,75434
# Coordenadas de Leganés (fila 11517): 40,339, -3,75199
# Coordenadas de Leganés (fila 11622): 40,317586, -3,755019
# Coordenadas de Leganés (fila 11625): 40,328601, -3,763826
# Coordenadas de Leganés (fila 11629): 40,320355, -3,777929
# Coordenadas de Leganés (fila 11630): 40,319574, -3,755102
# Coordenadas de Leganés (fila 11636): 40,319444, -3,753672
# Coordenadas de Leganés (fila 11637): 40,315913, -3,756759
# Coordenadas de Leganés (fila 11653): 40,33008, -3,76646
# Coordenadas de Leganés (fila 11676): 40,33218, -3,74921
# Coordenadas de Leganés (fila 11679): 40,3285125, -3,7624825
# Coordenadas de Leganés (fila 11688): 40,3574064, -3,7782684
# Coordenadas de Leganés (fila 11967): 40,3300242041513, -3,76550231421688
# Coordenadas de Leganés (fila 12110): 40,3201063, -3,7586646
# Coordenadas de Leganés (fila 12268): 40,33806, -3,75135
# Coordenadas de Leganés (fila 12274): 40,33385, -3,75161
# Coordenadas de Leganés (fila 12412): 40,331329, -3,770181
# Coordenadas de Leganés (fila 12553): 40,3310724737636, -3,77000578078649
# Coordenadas de Leganés (fila 12668): 40,32458, -3,77367
# Coordenadas de Leganés (fila 12859): 40,32739, -3,76408
# Coordenadas de Leganés (fila 12963): 40,33727, -3,7454
# Coordenadas de Leganés (fila 12969): 40,3241157864376, -3,77127578643763
# Coordenadas de Leganés (fila 12992): 40,3278234, -3,7630715
# Coordenadas de Leganés (fila 13007): 40,3335821864376, -3,76873891356237
# Coordenadas de Leganés (fila 13201): 40,3303391, -3,7544003
# Coordenadas de Leganés (fila 13202): 40,32901, -3,75009
# Coordenadas de Leganés (fila 13310): 40,3234, -3,77152
# Coordenadas de Leganés (fila 13451): 40,34538, -3,77261
# Coordenadas de Leganés (fila 13544): 40,33425, -3,76186
# Coordenadas de Leganés (fila 13550): 40,323754187848, -3,7730788126493
# Coordenadas de Leganés (fila 13590): 40,3313044150488, -3,75084400177002
# Coordenadas de Leganés (fila 13631): 40,3319065585014, -3,7759260276798
# Coordenadas de Leganés (fila 13640): 40,33158, -3,7602
# Coordenadas de Leganés (fila 13664): 40,32134, -3,76047
# Coordenadas de Leganés (fila 13702): 40,33189, -3,764
# Coordenadas de Leganés (fila 13716): 40,33595, -3,75278
# Coordenadas de Leganés (fila 13813): 40,3543087740551, -3,78119683423338
# Coordenadas de Leganés (fila 13858): 40,3308835864376, -3,77019188643763
# Coordenadas de Leganés (fila 13865): 40,3308835864376, -3,77019188643763
# Coordenadas de Leganés (fila 13938): 40,33163, -3,74655
# Coordenadas de Leganés (fila 13940): 40,32811, -3,76988
# Coordenadas de Leganés (fila 13953): 40,3194273, -3,7546246
# Coordenadas de Leganés (fila 14123): 40,3208104, -3,78076959999998
# Coordenadas de Leganés (fila 14137): 40,32845, -3,76772
# Coordenadas de Leganés (fila 14141): 40,33643, -3,75089
# Coordenadas de Leganés (fila 14168): 40,32845, -3,76772
# Coordenadas de Leganés (fila 14172): 40,33643, -3,75089
# Coordenadas de Leganés (fila 14525): 40,33595, -3,75278
# Coordenadas de Leganés (fila 14528): 40,32746, -3,76821
# Coordenadas de Leganés (fila 14625): 40,33383, -3,75547
# Coordenadas de Leganés (fila 14639): 40,3337657864376, -3,76824421356237
# Coordenadas de Leganés (fila 14640): 40,3337657864376, -3,76824421356237
# Coordenadas de Leganés (fila 14657): 40,33132, -3,76054
# Coordenadas de Leganés (fila 14691): 40,3210413, -3,779803
# Coordenadas de Leganés (fila 14769): 40,3366, -3,74658
# Coordenadas de Leganés (fila 14825): 40,33177, -3,773
# Coordenadas de Leganés (fila 14916): 40,33422, -3,76264
# Coordenadas de Leganés (fila 15015): 40,3571804504395, -3,78049993515015
# Coordenadas de Leganés (fila 15024): 40,32314, -3,78143
# Coordenadas de Leganés (fila 15238): 40,3337657864376, -3,76824421356237
# Coordenadas de Leganés (fila 15263): 40,32124, -3,7798
# Coordenadas de Leganés (fila 15291): 40,3259051, -3,76318

# %%
import pandas as pd

coord_leganes['latitude'] = ds['latitude'].str.split(',')
coord_leganes['latitude'] = ds['latitude'].apply(
    lambda x: [float(i) for i in x if i.isdigit()]  # Filter out non-digits
)

# %%
## HERE: plot the coordinates of the estates

coord_leganes = subset[subset["level5"] == "Leganés"][["latitude","longitude"]]
coord_getafe = subset[subset["level5"] == "Getafe"][["latitude","longitude"]]
coord_fuenlabrada = subset[subset["level5"] == "Fuenlabrada"][["latitude","longitude"]]
coord_alcorcon = subset[subset["level5"] == "Alcorcón"][["latitude","longitude"]]

## PUT HERE YOUR CODE:
dict_leganes = dict(zip(coord_leganes.columns, coord_leganes.values[0]))
dict_getafe = dict(zip(coord_getafe.columns,coord_getafe.values[0]))
dict_fuenlabrada = dict(zip(coord_fuenlabrada.columns,coord_fuenlabrada.values[0]))
dict_alcorcon = dict(zip(coord_alcorcon.columns,coord_alcorcon.values[0]))

from matplotlib.colors import to_rgb

color_leganes = to_rgb('red')
color_getafe = to_rgb('blue')
color_fuenlabrada = to_rgb('green')
color_alcorcon = to_rgb('yellow')


import folium

coord_leganes = ds.iloc[0].tolist()  # Convertir la fila a lista

# Crear un mapa centrado en una localización
m = folium.Map(location=[40,31933, -3,77574], zoom_start=12)  

# Crear un marcador para Leganés
folium.Marker(location=coord_leganes, 
              draggable=False, 
              popup="Leganés", 
              icon=folium.Icon(color='red')).add_to(m)


# Guardar el mapa como HTML
m.save('mapa.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 27
#      24 coord_leganes = ds.iloc[0].tolist()  # Convertir la fila a lista
#      26 # Crear un mapa centrado en una localización
# ---> 27 m = folium.Map(location=[40,31933, -3,77574], zoom_start=12)
#      29 # Crear un marcador para Leganés
#      30 folium.Marker(location=coord_leganes,
#      31               draggable=False,
#      32               popup="Leganés",
#      33               icon=folium.Icon(color='red')).add_to(m)
#
# File ~/.local/lib/python3.11/site-packages/folium/folium.py:278, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     276     zoom_start = 1
#     277 else:
# --> 278     self.location = validate_location(location)
#     280 Figure().add_child(self)
#     282 # Map Size Parameters.
#
# File ~/.local/lib/python3.11/site-packages/folium/utilities.py:81, in validate_location(location)
#      75     raise TypeError(
#      76         "Location should be a sized variable, "
#      77         "for example a list or a tuple, instead got "
#      78         f"{location!r} of type {type(location)}."
#      79     )
#      80 if len(location) != 2:
# ---> 81     raise ValueError(
#      82         "Expected two (lat, lon) values for location, "
#      83         f"instead got: {location!r}."
#      84     )
#      85 try:
#      86     coords = (location[0], location[1])
#
# ValueError: Expected two (lat, lon) values for location, instead got: [40, 31933, -3, 77574].
